# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
from keras import layers
from keras.callbacks import Callback, ModelCheckpoint, ReduceLROnPlateau
from keras.utils.np_utils import to_categorical
from keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
import pandas as pd
import scipy
from tqdm import tqdm
import tensorflow as tf
from collections import Counter
import json
import itertools
from keras.layers import Dense,Dropout,Activation,Add,MaxPooling2D,Conv2D,Flatten,BatchNormalization
import os
from PIL import Image
import cv2
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, roc_curve,roc_auc_score, auc
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Data Gathering and Preprocessing

# %%
# create data generator
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True
)

# Define the data generator for the validation and test sets
val_test_datagen = ImageDataGenerator(rescale=1./255)

# fit the model on data
train_generator = train_datagen.flow_from_directory(
    '/content/drive/MyDrive/Group_Project_Data/Train',
    target_size=(64,64),
    batch_size=32,
    class_mode='binary')
    
validation_generator = val_test_datagen.flow_from_directory(
    '/content/drive/MyDrive/Group_Project_Data/Valid',
    target_size=(64,64),
    batch_size=32,
    class_mode='binary')
# Out:
# Found 6000 images belonging to 2 classes.
# Found 2000 images belonging to 2 classes.

# %%
def Dataset_loader(DIR, RESIZE, sigmaX=10):
    IMG = []
    read = lambda imname: np.asarray(Image.open(imname).convert("RGB"))
    
    for root, _, files in os.walk(DIR):
        for file in files:
            if file.endswith('.png'):
                PATH = os.path.join(root,file)

                img = read(PATH)

                img = cv2.resize(img, (RESIZE,RESIZE))

                IMG.append(np.array(img))
    return IMG

real_train = np.array(Dataset_loader('/content/drive/MyDrive/Group_Project_Data/Train/Real',64))
fake_train = np.array(Dataset_loader('/content/drive/MyDrive/Group_Project_Data/Train/Fake',64))
real_test = np.array(Dataset_loader('/content/drive/MyDrive/Group_Project_Data/Valid/Real',64))
fake_test = np.array(Dataset_loader('/content/drive/MyDrive/Group_Project_Data/Valid/Fake',64))

# %%
# Create labels
real_train_label = np.ones(len(real_train))
fake_train_label = np.zeros(len(fake_train))
real_test_label = np.ones(len(real_test))
fake_test_label = np.zeros(len(fake_test))

# Merge data 
X_train = np.concatenate((real_train, fake_train), axis = 0)
Y_train = np.concatenate((real_train_label, fake_train_label), axis = 0)
X_test = np.concatenate((real_test, fake_test), axis = 0)
Y_test = np.concatenate((real_test_label, fake_test_label), axis = 0)

# Shuffle train data
s = np.arange(X_train.shape[0])
np.random.shuffle(s)
X_train = X_train[s]
Y_train = Y_train[s]

# Shuffle test data
s = np.arange(X_test.shape[0])
np.random.shuffle(s)
X_test = X_test[s]
Y_test = Y_test[s]

# %% [markdown]
# **Define Model Architecture**

# %%
# define input shape
input_shape = (64, 64, 3)

# define model architecture
model = tf.keras.Sequential([
    layers.Conv2D(8, (3, 3), activation='relu', input_shape=input_shape),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(16, (3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(32, (3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Flatten(),
    layers.Dense(16, activation='relu'),
    layers.Dropout(0.5), # Adding Dropout layer with a rate of 0.5
    layers.Dense(1, activation='sigmoid')
])

# compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 62, 62, 8)         224
#
#  max_pooling2d (MaxPooling2D  (None, 31, 31, 8)        0
#  )
#
#  conv2d_1 (Conv2D)           (None, 29, 29, 16)        1168
#
#  max_pooling2d_1 (MaxPooling  (None, 14, 14, 16)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 12, 12, 32)        4640
#
#  max_pooling2d_2 (MaxPooling  (None, 6, 6, 32)         0
#  2D)
#
#  flatten (Flatten)           (None, 1152)              0
#
#  dense (Dense)               (None, 16)                18448
#
#  dropout (Dropout)           (None, 16)                0
#
#  dense_1 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 24,497
# Trainable params: 24,497
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping

early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1)

#define the model checkpoint callback this will keep on saving the model as a physical file
model_checkpoint = ModelCheckpoint('cnn.h5', verbose=1, save_best_only=True)

# %% [markdown]
# **Train Model**

# %%
#define a function to fit the model
def fit_and_evaluate(train, test, EPOCHS=20, BATCH_SIZE=32):

    results = model.fit(train, epochs=EPOCHS, batch_size=BATCH_SIZE, callbacks=[early_stopping, model_checkpoint], 
              verbose=1, validation_data=test) 
    
    print("Val Score: ", model.evaluate(test))
    return results

# %%
n_folds=4

#save the model history in a list after fitting so that we can plot later
model_history = [] 

for i in range(n_folds):
    print("Training on Fold: ",i+1)

    model_history.append(fit_and_evaluate(train_generator,validation_generator))
    
    print("======="*12, end="\n\n\n")
# Out:
# Training on Fold:  1
# Epoch 1/20
# 188/188 [==============================] - ETA: 0s - loss: 0.0177 - accuracy: 0.9927
# Epoch 1: val_loss did not improve from 0.00017
# 188/188 [==============================] - 40s 212ms/step - loss: 0.0177 - accuracy: 0.9927 - val_loss: 8.8410e-04 - val_accuracy: 0.9995
# Epoch 2/20
# 188/188 [==============================] - ETA: 0s - loss: 0.0176 - accuracy: 0.9925
# Epoch 2: val_loss did not improve from 0.00017
# 188/188 [==============================] - 41s 216ms/step - loss: 0.0176 - accuracy: 0.9925 - val_loss: 0.0016 - val_accuracy: 0.9990
# Epoch 3/20
# 188/188 [==============================] - ETA: 0s - loss: 0.0176 - accuracy: 0.9913
# Epoch 3: val_loss did not improve from 0.00017
# 188/188 [==============================] - 41s 217ms/step - loss: 0.0176 - accuracy: 0.9913 - val_loss: 0.0011 - val_accuracy: 0.9995
# Epoch 4/20
# 188/188 [==============================] - ETA: 0s - loss: 0.0163 - accuracy: 0.9920
# Epoch 4: val_loss did not improve from 0.00017
# 188/188 [==============================] - 45s 239ms/step - loss: 0.0163 - accuracy: 0.9920 - val_loss: 8.6223e-04 - val_accuracy: 0.9995
# Epoch 5/20
# 188/188 [==============================] - ETA: 0s - loss: 0.0158 - accuracy: 0.9923
# Epoch 5: val_loss did not improve from 0.00017
# 188/188 [==============================] - 45s 239ms/step - loss: 0.0158 - accuracy: 0.9923 - val_loss: 7.0922e-04 - val_accuracy: 0.9995
# Epoch 6/20
# 188/188 [==============================] - ETA: 0s - loss: 0.0161 - accuracy: 0.9922
# Epoch 6: val_loss did not improve from 0.00017
# 188/188 [==============================] - 45s 239ms/step - loss: 0.0161 - accuracy: 0.9922 - val_loss: 6.9529e-04 - val_accuracy: 0.9995
# Epoch 7/20
# 188/188 [==============================] - ETA: 0s - loss: 0.0134 - accuracy: 0.9933
# Epoch 7: val_loss did not improve from 0.00017
# 188/188 [==============================] - 40s 215ms/step - loss: 0.0134 - accuracy: 0.9933 - val_loss: 6.8193e-04 - val_accuracy: 0.9995
# Epoch 8/20
# 188/188 [==============================] - ETA: 0s - loss: 0.0167 - accuracy: 0.9915
# Epoch 8: val_loss did not improve from 0.00017
# 188/188 [==============================] - 40s 212ms/step - loss: 0.0167 - accuracy: 0.9915 - val_loss: 5.1227e-04 - val_accuracy: 0.9995
# Epoch 9/20
# 188/188 [==============================] - ETA: 0s - loss: 0.0195 - accuracy: 0.9898
# Epoch 9: val_loss did not improve from 0.00017
# 188/188 [==============================] - 41s 219ms/step - loss: 0.0195 - accuracy: 0.9898 - val_loss: 4.3785e-04 - val_accuracy: 0.9995
# Epoch 10/20
# 188/188 [==============================] - ETA: 0s - loss: 0.0146 - accuracy: 0.9927
# Epoch 10: val_loss did not improve from 0.00017
# 188/188 [==============================] - 40s 211ms/step - loss: 0.0146 - accuracy: 0.9927 - val_loss: 2.1220e-04 - val_accuracy: 1.0000
# Epoch 11/20
# 188/188 [==============================] - ETA: 0s - loss: 0.0145 - accuracy: 0.9918
# Epoch 11: val_loss improved from 0.00017 to 0.00012, saving model to cnn.h5
# 188/188 [==============================] - 41s 218ms/step - loss: 0.0145 - accuracy: 0.9918 - val_loss: 1.2238e-04 - val_accuracy: 1.0000
# Epoch 12/20
# 188/188 [==============================] - ETA: 0s - loss: 0.0138 - accuracy: 0.9923
# Epoch 12: val_loss did not improve from 0.00012
# 188/188 [==============================] - 46s 247ms/step - loss: 0.0138 - accuracy: 0.9923 - val_loss: 2.6728e-04 - val_accuracy: 1.0000
# Epoch 13/20
# 188/188 [==============================] - ETA: 0s - loss: 0.0131 - accuracy: 0.9918
# Epoch 13: val_loss did not improve from 0.00012
# 188/188 [==============================] - 42s 222ms/step - loss: 0.0131 - accuracy: 0.9918 - val_loss: 2.7167e-04 - val_accuracy: 1.0000
# Epoch 14/20
# 188/188 [==============================] - ETA: 0s - loss: 0.0100 - accuracy: 0.9940
# Epoch 14: val_loss did not improve from 0.00012
# 188/188 [==============================] - 41s 219ms/step - loss: 0.0100 - accuracy: 0.9940 - val_loss: 2.5454e-04 - val_accuracy: 1.0000
# Epoch 14: early stopping
# 63/63 [==============================] - 5s 80ms/step - loss: 2.5454e-04 - accuracy: 1.0000
# Val Score:  [0.00025454399292357266, 1.0]
# ====================================================================================
#
#
# Training on Fold:  2
# Epoch 1/20
# 188/188 [==============================] - ETA: 0s - loss: 0.0130 - accuracy: 0.9922
# Epoch 1: val_loss did not improve from 0.00012
# 188/188 [==============================] - 41s 219ms/step - loss: 0.0130 - accuracy: 0.9922 - val_loss: 6.9582e-04 - val_accuracy: 0.9995
# Epoch 2/20
# 188/188 [==============================] - ETA: 0s - loss: 0.0143 - accuracy: 0.9903
# Epoch 2: val_loss did not improve from 0.00012
# 188/188 [==============================] - 40s 214ms/step - loss: 0.0143 - accuracy: 0.9903 - val_loss: 4.8913e-04 - val_accuracy: 0.9995
# Epoch 3/20
# 188/188 [==============================] - ETA: 0s - loss: 0.0125 - accuracy: 0.9920
# Epoch 3: val_loss did not improve from 0.00012
# 188/188 [==============================] - 45s 237ms/step - loss: 0.0125 - accuracy: 0.9920 - val_loss: 3.4420e-04 - val_accuracy: 1.0000
# Epoch 4/20
# 188/188 [==============================] - ETA: 0s - loss: 0.0122 - accuracy: 0.9918
# Epoch 4: val_loss did not improve from 0.00012
# 188/188 [==============================] - 44s 237ms/step - loss: 0.0122 - accuracy: 0.9918 - val_loss: 2.7952e-04 - val_accuracy: 1.0000
# Epoch 5/20
# 188/188 [==============================] - ETA: 0s - loss: 0.0136 - accuracy: 0.9910
# Epoch 5: val_loss did not improve from 0.00012
# 188/188 [==============================] - 45s 239ms/step - loss: 0.0136 - accuracy: 0.9910 - val_loss: 2.3902e-04 - val_accuracy: 1.0000
# Epoch 6/20
# 188/188 [==============================] - ETA: 0s - loss: 0.0114 - accuracy: 0.9915
# Epoch 6: val_loss did not improve from 0.00012
# 188/188 [==============================] - 45s 237ms/step - loss: 0.0114 - accuracy: 0.9915 - val_loss: 2.1191e-04 - val_accuracy: 1.0000
# Epoch 7/20
# 188/188 [==============================] - ETA: 0s - loss: 0.0116 - accuracy: 0.9925
# Epoch 7: val_loss did not improve from 0.00012
# 188/188 [==============================] - 41s 215ms/step - loss: 0.0116 - accuracy: 0.9925 - val_loss: 1.8500e-04 - val_accuracy: 1.0000
# Epoch 8/20
# 188/188 [==============================] - ETA: 0s - loss: 0.0112 - accuracy: 0.9923
# Epoch 8: val_loss did not improve from 0.00012
# 188/188 [==============================] - 40s 212ms/step - loss: 0.0112 - accuracy: 0.9923 - val_loss: 0.0017 - val_accuracy: 0.9990
# Epoch 9/20
# 188/188 [==============================] - ETA: 0s - loss: 0.0157 - accuracy: 0.9917
# Epoch 9: val_loss did not improve from 0.00012
# 188/188 [==============================] - 41s 218ms/step - loss: 0.0157 - accuracy: 0.9917 - val_loss: 0.0034 - val_accuracy: 0.9980
# Epoch 10/20
# 188/188 [==============================] - ETA: 0s - loss: 0.0130 - accuracy: 0.9908
# Epoch 10: val_loss did not improve from 0.00012
# 188/188 [==============================] - 42s 223ms/step - loss: 0.0130 - accuracy: 0.9908 - val_loss: 5.1209e-04 - val_accuracy: 0.9995
# Epoch 10: early stopping
# 63/63 [==============================] - 6s 102ms/step - loss: 5.1209e-04 - accuracy: 0.9995
# Val Score:  [0.0005120886489748955, 0.9994999766349792]
# ====================================================================================
#
#
# Training on Fold:  3
# Epoch 1/20
# 188/188 [==============================] - ETA: 0s - loss: 0.0121 - accuracy: 0.9910
# Epoch 1: val_loss improved from 0.00012 to 0.00002, saving model to cnn.h5
# 188/188 [==============================] - 41s 219ms/step - loss: 0.0121 - accuracy: 0.9910 - val_loss: 2.0752e-05 - val_accuracy: 1.0000
# Epoch 2/20
# 188/188 [==============================] - ETA: 0s - loss: 0.0119 - accuracy: 0.9918
# Epoch 2: val_loss did not improve from 0.00002
# 188/188 [==============================] - 40s 215ms/step - loss: 0.0119 - accuracy: 0.9918 - val_loss: 6.3577e-05 - val_accuracy: 1.0000
# Epoch 3/20
# 188/188 [==============================] - ETA: 0s - loss: 0.0114 - accuracy: 0.9925
# Epoch 3: val_loss did not improve from 0.00002
# 188/188 [==============================] - 41s 219ms/step - loss: 0.0114 - accuracy: 0.9925 - val_loss: 7.9189e-05 - val_accuracy: 1.0000
# Epoch 4/20
# 188/188 [==============================] - ETA: 0s - loss: 0.0105 - accuracy: 0.9927
# Epoch 4: val_loss did not improve from 0.00002
# 188/188 [==============================] - 42s 225ms/step - loss: 0.0105 - accuracy: 0.9927 - val_loss: 8.1407e-05 - val_accuracy: 1.0000
# Epoch 4: early stopping
# 63/63 [==============================] - 6s 94ms/step - loss: 8.1407e-05 - accuracy: 1.0000
# Val Score:  [8.14067097962834e-05, 1.0]
# ====================================================================================
#
#
# Training on Fold:  4
# Epoch 1/20
# 188/188 [==============================] - ETA: 0s - loss: 0.0300 - accuracy: 0.9875
# Epoch 1: val_loss did not improve from 0.00002
# 188/188 [==============================] - 41s 217ms/step - loss: 0.0300 - accuracy: 0.9875 - val_loss: 0.0071 - val_accuracy: 0.9980
# Epoch 2/20
# 188/188 [==============================] - ETA: 0s - loss: 0.0139 - accuracy: 0.9915
# Epoch 2: val_loss did not improve from 0.00002
# 188/188 [==============================] - 42s 225ms/step - loss: 0.0139 - accuracy: 0.9915 - val_loss: 7.6747e-04 - val_accuracy: 0.9995
# Epoch 3/20
# 188/188 [==============================] - ETA: 0s - loss: 0.0129 - accuracy: 0.9913
# Epoch 3: val_loss did not improve from 0.00002
# 188/188 [==============================] - 42s 224ms/step - loss: 0.0129 - accuracy: 0.9913 - val_loss: 8.7359e-04 - val_accuracy: 0.9990
# Epoch 4/20
# 188/188 [==============================] - ETA: 0s - loss: 0.0119 - accuracy: 0.9917
# Epoch 4: val_loss did not improve from 0.00002
# 188/188 [==============================] - 42s 223ms/step - loss: 0.0119 - accuracy: 0.9917 - val_loss: 6.4566e-04 - val_accuracy: 0.9995
# Epoch 5/20
# 188/188 [==============================] - ETA: 0s - loss: 0.0109 - accuracy: 0.9933
# Epoch 5: val_loss did not improve from 0.00002
# 188/188 [==============================] - 45s 240ms/step - loss: 0.0109 - accuracy: 0.9933 - val_loss: 5.2105e-04 - val_accuracy: 0.9995
# Epoch 6/20
# 188/188 [==============================] - ETA: 0s - loss: 0.0102 - accuracy: 0.9928
# Epoch 6: val_loss did not improve from 0.00002
# 188/188 [==============================] - 45s 241ms/step - loss: 0.0102 - accuracy: 0.9928 - val_loss: 5.1434e-04 - val_accuracy: 0.9995
# Epoch 7/20
# 188/188 [==============================] - ETA: 0s - loss: 0.0110 - accuracy: 0.9933
# Epoch 7: val_loss did not improve from 0.00002
# 188/188 [==============================] - 41s 218ms/step - loss: 0.0110 - accuracy: 0.9933 - val_loss: 5.0582e-04 - val_accuracy: 0.9995
# Epoch 8/20
# 188/188 [==============================] - ETA: 0s - loss: 0.0116 - accuracy: 0.9913
# Epoch 8: val_loss did not improve from 0.00002
# 188/188 [==============================] - 45s 241ms/step - loss: 0.0116 - accuracy: 0.9913 - val_loss: 4.9253e-04 - val_accuracy: 0.9995
# Epoch 9/20
# 188/188 [==============================] - ETA: 0s - loss: 0.0113 - accuracy: 0.9913
# Epoch 9: val_loss did not improve from 0.00002
# 188/188 [==============================] - 45s 241ms/step - loss: 0.0113 - accuracy: 0.9913 - val_loss: 4.2798e-04 - val_accuracy: 0.9995
# Epoch 10/20
# 188/188 [==============================] - ETA: 0s - loss: 0.0105 - accuracy: 0.9925
# Epoch 10: val_loss did not improve from 0.00002
# 188/188 [==============================] - 42s 223ms/step - loss: 0.0105 - accuracy: 0.9925 - val_loss: 4.4669e-04 - val_accuracy: 0.9995
# Epoch 11/20
# 188/188 [==============================] - ETA: 0s - loss: 0.0099 - accuracy: 0.9927
# Epoch 11: val_loss did not improve from 0.00002
# 188/188 [==============================] - 41s 217ms/step - loss: 0.0099 - accuracy: 0.9927 - val_loss: 4.3446e-04 - val_accuracy: 0.9995
# Epoch 12/20
# 188/188 [==============================] - ETA: 0s - loss: 0.0111 - accuracy: 0.9920
# Epoch 12: val_loss did not improve from 0.00002
# 188/188 [==============================] - 39s 206ms/step - loss: 0.0111 - accuracy: 0.9920 - val_loss: 4.1589e-04 - val_accuracy: 0.9995
# Epoch 13/20
# 188/188 [==============================] - ETA: 0s - loss: 0.0108 - accuracy: 0.9915
# Epoch 13: val_loss did not improve from 0.00002
# 188/188 [==============================] - 40s 211ms/step - loss: 0.0108 - accuracy: 0.9915 - val_loss: 3.5453e-04 - val_accuracy: 0.9995
# Epoch 14/20
# 188/188 [==============================] - ETA: 0s - loss: 0.0125 - accuracy: 0.9917
# Epoch 14: val_loss did not improve from 0.00002
# 188/188 [==============================] - 40s 214ms/step - loss: 0.0125 - accuracy: 0.9917 - val_loss: 5.1429e-04 - val_accuracy: 0.9995
# Epoch 15/20
# 188/188 [==============================] - ETA: 0s - loss: 0.0144 - accuracy: 0.9910
# Epoch 15: val_loss improved from 0.00002 to 0.00002, saving model to cnn.h5
# 188/188 [==============================] - 40s 211ms/step - loss: 0.0144 - accuracy: 0.9910 - val_loss: 1.6969e-05 - val_accuracy: 1.0000
# Epoch 16/20
# 188/188 [==============================] - ETA: 0s - loss: 0.0105 - accuracy: 0.9923
# Epoch 16: val_loss improved from 0.00002 to 0.00000, saving model to cnn.h5
# 188/188 [==============================] - 40s 211ms/step - loss: 0.0105 - accuracy: 0.9923 - val_loss: 4.0817e-06 - val_accuracy: 1.0000
# Epoch 17/20
# 188/188 [==============================] - ETA: 0s - loss: 0.0099 - accuracy: 0.9930
# Epoch 17: val_loss improved from 0.00000 to 0.00000, saving model to cnn.h5
# 188/188 [==============================] - 40s 214ms/step - loss: 0.0099 - accuracy: 0.9930 - val_loss: 1.1674e-06 - val_accuracy: 1.0000
# Epoch 18/20
# 188/188 [==============================] - ETA: 0s - loss: 0.0112 - accuracy: 0.9920
# Epoch 18: val_loss improved from 0.00000 to 0.00000, saving model to cnn.h5
# 188/188 [==============================] - 41s 216ms/step - loss: 0.0112 - accuracy: 0.9920 - val_loss: 6.5253e-07 - val_accuracy: 1.0000
# Epoch 19/20
# 188/188 [==============================] - ETA: 0s - loss: 0.0089 - accuracy: 0.9933
# Epoch 19: val_loss improved from 0.00000 to 0.00000, saving model to cnn.h5
# 188/188 [==============================] - 41s 216ms/step - loss: 0.0089 - accuracy: 0.9933 - val_loss: 3.5107e-08 - val_accuracy: 1.0000
# Epoch 20/20
# 188/188 [==============================] - ETA: 0s - loss: 0.0122 - accuracy: 0.9917
# Epoch 20: val_loss did not improve from 0.00000
# 188/188 [==============================] - 40s 213ms/step - loss: 0.0122 - accuracy: 0.9917 - val_loss: 4.0158e-07 - val_accuracy: 1.0000
# 63/63 [==============================] - 5s 81ms/step - loss: 4.0158e-07 - accuracy: 1.0000
# Val Score:  [4.015814170088561e-07, 1.0]
# ====================================================================================

# %% [markdown]
# Evalute Model

# %%
# iterate over the model history for all folds
for i, history in enumerate(model_history):
    # extract the loss and accuracy values for training and validation data
    fold_train_loss = history.history['loss']
    fold_val_loss = history.history['val_loss']
    fold_train_acc = history.history['accuracy']
    fold_val_acc = history.history['val_accuracy']
    
    # create a line plot for the loss values of the current fold
    plt.figure(figsize=(6, 4))
    plt.plot(fold_train_loss, label='Training Loss')
    plt.plot(fold_val_loss, label='Validation Loss')
    plt.title('Fold {} - Loss'.format(i+1))
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()
    
    # create a line plot for the accuracy values of the current fold
    plt.figure(figsize=(6, 4))
    plt.plot(fold_train_acc, label='Training Accuracy')
    plt.plot(fold_val_acc, label='Validation Accuracy')
    plt.title('Fold {} - Accuracy'.format(i+1))
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.show()

# %%
out = model.evaluate(validation_generator)
print(out[1])
# Out:
# 63/63 [==============================] - 6s 98ms/step - loss: 4.0158e-07 - accuracy: 1.0000
# 1.0

# %%
from sklearn.metrics import classification_report, roc_curve, auc

# Make predictions on the X_test
y_pred_prob = model.predict(validation_generator)

# Round the predicted probabilities using the optimal threshold
y_pred = np.round(y_pred_prob)

# Get the class names from the generator
class_names = list(validation_generator.class_indices.keys())

# Generate classification report
print(classification_report(validation_generator.classes,y_pred, target_names=class_names))
# Out:
# 63/63 [==============================] - 6s 100ms/step
#               precision    recall  f1-score   support
#
#         Fake       0.50      0.50      0.50      1000
#         Real       0.50      0.50      0.50      1000
#
#     accuracy                           0.50      2000
#    macro avg       0.50      0.50      0.50      2000
# weighted avg       0.50      0.50      0.50      2000

# %%
# plot confusion matrix
confusion_mtx = confusion_matrix(validation_generator.classes,y_pred)
plt.imshow(confusion_mtx, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names, rotation=45)
plt.yticks(tick_marks, class_names)
for i in range(confusion_mtx.shape[0]):
    for j in range(confusion_mtx.shape[1]):
        plt.text(j, i, str(confusion_mtx[i, j]), horizontalalignment='center', verticalalignment='center')
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

# %%
fpr, tpr, thresholds = roc_curve(validation_generator.classes,y_pred)
roc_auc = auc(fpr, tpr)

# plot ROC curve
plt.plot(fpr, tpr, color='darkorange', label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()

# %%
# Make predictions on the X_test
y_pred_prob = model.predict(X_test)

# Round the predicted probabilities using the optimal threshold
y_pred = np.round(y_pred_prob)

# Get the class names from the generator
class_names = list(validation_generator.class_indices.keys())

# Generate classification report
print(classification_report(Y_test,y_pred, target_names=class_names))
# Out:
# 63/63 [==============================] - 2s 27ms/step
#               precision    recall  f1-score   support
#
#         Fake       1.00      0.98      0.99      1000
#         Real       0.99      1.00      0.99      1000
#
#     accuracy                           0.99      2000
#    macro avg       0.99      0.99      0.99      2000
# weighted avg       0.99      0.99      0.99      2000

# %%
# plot confusion matrix
confusion_mtx = confusion_matrix(Y_test,y_pred)
plt.imshow(confusion_mtx, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names, rotation=45)
plt.yticks(tick_marks, class_names)
for i in range(confusion_mtx.shape[0]):
    for j in range(confusion_mtx.shape[1]):
        plt.text(j, i, str(confusion_mtx[i, j]), horizontalalignment='center', verticalalignment='center')
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

# %%
fpr, tpr, thresholds = roc_curve(Y_test,y_pred)
roc_auc = auc(fpr, tpr)

# plot ROC curve
plt.plot(fpr, tpr, color='darkorange', label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# Model Output

# %%
# Plot some images with their predicted and real labels
fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(10,10))
for i, ax in enumerate(axes.flat):
    ax.imshow(X_test[i])
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_title(f"Pred Label: {y_pred[i]}, True Label: {Y_test[i]}")
    
plt.tight_layout()
plt.show()
